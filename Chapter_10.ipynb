# %% [markdown]
# <a href="https://colab.research.google.com/github/waseemhaider01/Html-Css/blob/main/Chapter_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit==2.1
# Out:
# Collecting qiskit==2.1
#   Downloading qiskit-2.1.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit==2.1)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit==2.1) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit==2.1) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit==2.1) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit==2.1)
#   Downloading stevedore-5.8.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit==2.1) (4.15.0)
# Downloading qiskit-2.1.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 26.8 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.1 MB/s eta 0:00:00
# Downloading stevedore-5.8.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit
# Successfully installed qiskit-2.1.0 rustworkx-0.17.1 stevedore-5.8.0

# %%
pip install qiskit_aer==0.17
# Out:
# Collecting qiskit_aer==0.17
#   Downloading qiskit_aer-0.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer==0.17) (2.1.0)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer==0.17) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer==0.17) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit_aer==0.17) (5.9.5)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer==0.17) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer==0.17) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer==0.17) (5.8.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit_aer==0.17) (4.15.0)
# Downloading qiskit_aer-0.17.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 66.6 MB/s eta 0:00:00
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.17.0

# %%
pip install qiskit_ibm_runtime==0.40
# Out:
# Collecting qiskit_ibm_runtime==0.40
#   Downloading qiskit_ibm_runtime-0.40.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime==0.40)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (2.0.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (2.9.0.post0)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime==0.40)
#   Downloading ibm_platform_services-0.75.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (2.12.3)
# Requirement already satisfied: qiskit>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime==0.40) (26.2)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime==0.40)
#   Downloading ibm_cloud_sdk_core-3.24.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime==0.40) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime==0.40) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime==0.40) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.0->qiskit_ibm_runtime==0.40) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime==0.40) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit_ibm_runtime==0.40) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit_ibm_runtime==0.40) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit_ibm_runtime==0.40) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.4.1->qiskit_ibm_runtime==0.40) (5.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit_ibm_runtime==0.40) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit_ibm_runtime==0.40) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit_ibm_runtime==0.40) (2026.5.20)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime==0.40) (48.0.1)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime==0.40)
#   Downloading pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime==0.40) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.22.6->qiskit_ibm_runtime==0.40) (2.13.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime==0.40) (3.0)
# Downloading qiskit_ibm_runtime-0.40.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 27.9 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.75.1-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 29.3 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading ibm_cloud_sdk_core-3.24.4-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 2.9 MB/s eta 0:00:00
# Downloading pyspnego-0.12.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: ibm_cloud_sdk_core, pyspnego, ibm-platform-services, requests-ntlm, qiskit_ibm_runtime
# Successfully installed ibm-platform-services-0.75.1 ibm_cloud_sdk_core-3.24.4 pyspnego-0.12.1 qiskit_ibm_runtime-0.40.0 requests-ntlm-1.3.0

# %%
pip install numpy==2.2
# Out:
# Requirement already satisfied: numpy==2.2 in /usr/local/lib/python3.12/dist-packages (2.2.0)

# %%
pip install pylatexenc==2.10
# Out:
# Collecting pylatexenc==2.10
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=6cfd73ce15960e09a8a6972d4217cba6cf94d89c327c41aef471ff0d9de27493
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
pip install matplotlib==3.10
# Out:
# Requirement already satisfied: matplotlib==3.10 in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.10) (1.17.0)

# %% [markdown]
# # Chapter 10. Coding with Many Qubits in Qiskit

# %% [markdown]
# ## 10.1. Working with many qubits in Qiskit

# %%
from qiskit import QuantumCircuit

# %%
# Create a qubit with 5 qubits:
qc = QuantumCircuit(5)
# Apply the Toffoli gate:
qc.ccx(0,2,3)
qc.draw("mpl")

# %%
qc.mcx([0,3,4],2)
qc.draw("mpl")

# %% [markdown]
# ### Using registers

# %%
qc.measure_all()
print("Quantum registers:", qc.qregs)
print("Classical registers:", qc.cregs)
# Out:
# Quantum registers: [QuantumRegister(5, 'q')]
# Classical registers: [ClassicalRegister(5, 'meas')]

# %%
from qiskit import QuantumRegister, ClassicalRegister

qc.new_qreg = QuantumRegister(1, name = "new")
qc.new_creg = ClassicalRegister(10, name = "new_c")
qc.add_register(qc.new_qreg, qc.new_creg)

# %%
print("Quantum registers:", qc.qregs)
print("Classical registers:", qc.cregs)
qc.draw("mpl")
# Out:
# Quantum registers: [QuantumRegister(5, 'q'), QuantumRegister(1, 'new')]
# Classical registers: [ClassicalRegister(5, 'meas'), ClassicalRegister(10, 'new_c')]

# %% [markdown]
# ### How to verify the equivalence of circuits

# %%
tof = QuantumCircuit(3)
tof.h(2)
tof.cx(1,2)
tof.tdg(2)
tof.cx(0,2)
tof.t(2)
tof.cx(1,2)
tof.tdg(2)
tof.cx(0,2)
tof.t(1)
tof.t(2)
tof.cx(0,1)
tof.h(2)
tof.t(0)
tof.tdg(1)
tof.cx(0,1)
tof.draw("mpl") # Draw it to check it!

# %%
from qiskit.quantum_info import Operator
real_tof = QuantumCircuit(3)
real_tof.ccx(0,1,2) # This circuit has the actual Toffoli gate.

# Check if the operators are equal:
print(Operator(tof) == Operator(real_tof))
# Out:
# True

# %% [markdown]
# ## 10.2. Quantum teleportation

# %%
qt = QuantumCircuit(3)
qt.h(1)
qt.cx(1,2)
qt.cx(0,1)
qt.h(0)

# %%
qt.aux = ClassicalRegister(2, name = "aux")
qt.add_register(qt.aux)

qt.measure(0, qt.aux[0])
qt.measure(1, qt.aux[1])

# %%
# Apply X on qubit 2 if aux[1] == 1
with qt.if_test((qt.cregs[0][1], 1)):
    qt.x(2)

# Apply Z on qubit 2 if aux[0] == 1
with qt.if_test((qt.cregs[0][0], 1)):
    qt.z(2)

# %%
qt.final = ClassicalRegister(1, name = "final")
qt.add_register(qt.final)
qt.measure(2,qt.final)

# %%
qt.draw("mpl")

# %%
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import SamplerV2 as Sampler

backend = AerSimulator(seed_simulator = 18620123)
sampler = Sampler(backend)

# %%
def quantum_teleportation(state_preparation):
    # Compose the state_preparation circuit with qt.
	# We use front = True for state_preparation to go before qt.
    circuit = qt.compose(state_preparation, front = True)
    # Get the results.
    job = sampler.run([circuit])
    return job.result()[0].data.final

# %%
result_0 = quantum_teleportation(QuantumCircuit(1))
print(result_0.get_counts())
# Out:
# {'0': 1024}

# %%
state_plus = QuantumCircuit(1)
state_plus.h(0)

result_plus = quantum_teleportation(state_plus)
print(result_plus.get_counts())
# Out:
# {'1': 513, '0': 511}

# %% [markdown]
# ## 10.3 The Deutsch-Jozsa algorithm

# %% [markdown]
# ### Let's build some oracles

# %%
def build_oracle(strings_one):
    # If the function is never 1, the oracle is the identity.
    # Hence, we return an empty circuit.
    if len(strings_one) == 0:
        return QuantumCircuit()

    # Number of bits that the function takes as input:
    n = len(strings_one[0])

    qc = QuantumCircuit(n+1)
    for x in strings_one:
        # Find the positions in the string x where the bit is 0.
        # For this, we find the list of indices i such that x[i]=='0'.
        bits_zero = []
        for i in range(len(x)):
            val = x[i]
            if val == '0':
                bits_zero.append(i)

        # Step 1 in our construction.
        for bit in bits_zero:
            qc.x(bit)

        # Step 2.
        qc.mcx(list(range(n)), n)

        # Step 3.
        for bit in bits_zero:
            qc.x(bit)

    return qc

# %%
build_oracle(["000", "100", "111"]).draw("mpl")

# %%
def DJ(oracle):
    # Number of qubits in the circuit (same as the oracle).
    # If we are working with an n-bit function, nqubits = n + 1.
    nqubits = oracle.num_qubits

    # Create a circuit with (nqubits) qubits and (nqubits-1) bits.
    # Remember we are only going to measure the first (nqubits-1) qubits!
    qc = QuantumCircuit(nqubits, nqubits - 1)

    # Initialize the bottom qubit to |1>.
    qc.x(nqubits - 1)

    for i in range(nqubits):
        qc.h(i)
    qc.barrier()
    qc = qc.compose(oracle)
    qc.barrier()
    for i in range(nqubits - 1):
        qc.h(i)
        qc.measure(i,i)
    return qc

# %%
oracle = QuantumCircuit(4)
dj = DJ(oracle)
dj.draw("mpl")

# %%
job = sampler.run([dj], shots = 1)
result = job.result()[0].data.c
print(result.get_bitstrings())
# Out:
# ['000']

# %%
# Oracle of a balanced function (takes the value 1 with four inputs):
oracle = build_oracle(["000", "101", "100", "110"])
# Prepare the D-J circuit:
dj = DJ(oracle)
# Run it!
job = sampler.run([dj], shots = 1)
result = job.result()[0].data.c
print(result.get_bitstrings())
# Out:
# ['010']

# %% [markdown]
# ## 10.4 The Bernstein-Vazirani algorithm

# %%
oracle = build_oracle(["001", "011", "100", "110"])
dj = DJ(oracle)
job = sampler.run([dj], shots = 1)
result = job.result()[0].data.c
print(result.get_bitstrings())
# Out:
# ['101']
